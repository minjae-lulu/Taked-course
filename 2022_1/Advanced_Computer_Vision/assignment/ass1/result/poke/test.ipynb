# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive/My Drive/homeworks/dgms/code
# Out:
# /content/gdrive/My Drive/homeworks/dgms/code

# %%
ls
# Out:
# 11.py  12.py  model.pth  model.py  __pycache__/  test.ipynb  utils.py

# %%
# !python 12.py
# Out:
# Traceback (most recent call last):
#   File "12.py", line 326, in <module>
#     main()
#   File "12.py", line 322, in main
#     tester = Tester_other(batchSize)
#   File "12.py", line 259, in __init__
#     self._build_model()
#   File "12.py", line 280, in _build_model
#     self.net = net.to(device)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 907, in to
#     return self._apply(convert)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 578, in _apply
#     module._apply(fn)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 578, in _apply
#     module._apply(fn)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 578, in _apply
#     module._apply(fn)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 601, in _apply
#     param_applied = fn(param)
# ...
